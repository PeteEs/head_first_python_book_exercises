# %%
import os

import swimclub

# %%
swim_files = os.listdir(swimclub.FOLDER)
swim_files.remove('.DS_Store')

print(len(swim_files))
# Out:
# 60

# %%
swimmers = []

for swim_file in swim_files:
    swimmer, *_ = swimclub.read_swim_data(swim_file)
    swimmers.append(swimmer)

print(swimmers)
# Out:
# ['Abi', 'Abi', 'Abi', 'Abi', 'Abi', 'Ali', 'Ali', 'Alison', 'Alison', 'Aurora', 'Bill', 'Bill', 'Blake', 'Blake', 'Blake', 'Calvin', 'Calvin', 'Calvin', 'Carl', 'Chris', 'Chris', 'Darius', 'Darius', 'Darius', 'Darius', 'Dave', 'Dave', 'Elba', 'Emma', 'Emma', 'Erika', 'Erika', 'Erika', 'Hannah', 'Hannah', 'Katie', 'Katie', 'Katie', 'Katie', 'Katie', 'Katie', 'Katie', 'Lizzie', 'Lizzie', 'Maria', 'Mike', 'Mike', 'Mike', 'Mike', 'Mike', 'Owen', 'Ruth', 'Ruth', 'Ruth', 'Ruth', 'Ruth', 'Tasmin', 'Tasmin', 'Tasmin', 'Tasmin']

# %%
swimmers =[]

for file in swim_files:
    swimmers.append(swimclub.read_swim_data(file)[0])

print(swimmers)
# Out:
# ['Abi', 'Abi', 'Abi', 'Abi', 'Abi', 'Ali', 'Ali', 'Alison', 'Alison', 'Aurora', 'Bill', 'Bill', 'Blake', 'Blake', 'Blake', 'Calvin', 'Calvin', 'Calvin', 'Carl', 'Chris', 'Chris', 'Darius', 'Darius', 'Darius', 'Darius', 'Dave', 'Dave', 'Elba', 'Emma', 'Emma', 'Erika', 'Erika', 'Erika', 'Hannah', 'Hannah', 'Katie', 'Katie', 'Katie', 'Katie', 'Katie', 'Katie', 'Katie', 'Lizzie', 'Lizzie', 'Maria', 'Mike', 'Mike', 'Mike', 'Mike', 'Mike', 'Owen', 'Ruth', 'Ruth', 'Ruth', 'Ruth', 'Ruth', 'Tasmin', 'Tasmin', 'Tasmin', 'Tasmin']

# %%
names = list(set(swimmers))

# %%
print(names)
# Out:
# ['Lizzie', 'Dave', 'Erika', 'Carl', 'Emma', 'Aurora', 'Blake', 'Owen', 'Abi', 'Calvin', 'Ruth', 'Elba', 'Mike', 'Bill', 'Maria', 'Chris', 'Hannah', 'Alison', 'Ali', 'Darius', 'Tasmin', 'Katie']

# %%
swimmers = []

for file in swim_files:
    name = swimclub.read_swim_data(file)[0]
    if name not in swimmers:
        swimmers.append(name)

print(swimmers)
# Out:
# ['Abi', 'Ali', 'Alison', 'Aurora', 'Bill', 'Blake', 'Calvin', 'Carl', 'Chris', 'Darius', 'Dave', 'Elba', 'Emma', 'Erika', 'Hannah', 'Katie', 'Lizzie', 'Maria', 'Mike', 'Owen', 'Ruth', 'Tasmin']

# %%
print(sorted(names))
# Out:
# ['Abi', 'Ali', 'Alison', 'Aurora', 'Bill', 'Blake', 'Calvin', 'Carl', 'Chris', 'Darius', 'Dave', 'Elba', 'Emma', 'Erika', 'Hannah', 'Katie', 'Lizzie', 'Maria', 'Mike', 'Owen', 'Ruth', 'Tasmin']

# %%
print(sorted(swimmers))
# Out:
# ['Abi', 'Ali', 'Alison', 'Aurora', 'Bill', 'Blake', 'Calvin', 'Carl', 'Chris', 'Darius', 'Dave', 'Elba', 'Emma', 'Erika', 'Hannah', 'Katie', 'Lizzie', 'Maria', 'Mike', 'Owen', 'Ruth', 'Tasmin']

# %%
swimmers = []
for file in swim_files:
    swimclub.read_swim_data(file)[0]
    swimmers.append((swimclub.read_swim_data(file)[0], file))

# %%
len(swim_files)
# Out:
# 60

# %%
swimmers[:5]
# Out:
# [('Abi', 'Abi-10-100m-Back.txt'),
#  ('Abi', 'Abi-10-100m-Breast.txt'),
#  ('Abi', 'Abi-10-50m-Back.txt'),
#  ('Abi', 'Abi-10-50m-Breast.txt'),
#  ('Abi', 'Abi-10-50m-Free.txt')]

# %%
names = []

for row in swimmers:
    if row[0] not in names:
        names.append(row[0])

print(sorted(names))
# Out:
# ['Abi', 'Ali', 'Alison', 'Aurora', 'Bill', 'Blake', 'Calvin', 'Carl', 'Chris', 'Darius', 'Dave', 'Elba', 'Emma', 'Erika', 'Hannah', 'Katie', 'Lizzie', 'Maria', 'Mike', 'Owen', 'Ruth', 'Tasmin']

# %%
for n, event in enumerate(swimmers):
    if event[0] == "Dave":
        print(n, event)
# Out:
# 25 ('Dave', 'Dave-17-100m-Free.txt')
# 26 ('Dave', 'Dave-17-200m-Back.txt')

# %%
person = {
    "first": "Tim",
    "last": "O'Reilly"
}

# %%
person['first']
# Out:
# 'Tim'

# %%
person = ['last']

# %%
swimmers = {}

# %%
for file in swim_files:
    name, *_ = swimclub.read_swim_data(file)
    swimmers[name] = []

# %%
print(swimmers)
# Out:
# {'Abi': [], 'Ali': [], 'Alison': [], 'Aurora': [], 'Bill': [], 'Blake': [], 'Calvin': [], 'Carl': [], 'Chris': [], 'Darius': [], 'Dave': [], 'Elba': [], 'Emma': [], 'Erika': [], 'Hannah': [], 'Katie': [], 'Lizzie': [], 'Maria': [], 'Mike': [], 'Owen': [], 'Ruth': [], 'Tasmin': []}

# %%
len(swimmers)
# Out:
# 22

# %%
print(sorted(swimmers))
# Out:
# ['Abi', 'Ali', 'Alison', 'Aurora', 'Bill', 'Blake', 'Calvin', 'Carl', 'Chris', 'Darius', 'Dave', 'Elba', 'Emma', 'Erika', 'Hannah', 'Katie', 'Lizzie', 'Maria', 'Mike', 'Owen', 'Ruth', 'Tasmin']

# %%
swimmers = {}

# %%
for file in swim_files:
    name, *_ = swimclub.read_swim_data(file)
    if name not in swimmers:
        swimmers[name] = []

    swimmers[name].append(file)

# %%
for swimmer in swimmers:
    print(swimmer, swimmers[swimmer])
# Out:
# Abi ['Abi-10-100m-Breast.txt', 'Abi-10-50m-Back.txt', 'Abi-10-50m-Breast.txt', 'Abi-10-50m-Free.txt', 'Abi-10-100m-Back.txt', 'Abi-10-100m-Breast.txt', 'Abi-10-50m-Back.txt', 'Abi-10-50m-Breast.txt', 'Abi-10-50m-Free.txt']
# Ali ['Ali-12-100m-Free.txt', 'Ali-12-100m-Back.txt', 'Ali-12-100m-Free.txt']
# Alison ['Alison-14-100m-Free.txt', 'Alison-14-100m-Breast.txt', 'Alison-14-100m-Free.txt']
# Aurora ['Aurora-13-50m-Free.txt']
# Bill ['Bill-18-200m-Back.txt', 'Bill-18-100m-Back.txt', 'Bill-18-200m-Back.txt']
# Blake ['Blake-15-100m-Fly.txt', 'Blake-15-100m-Free.txt', 'Blake-15-100m-Back.txt', 'Blake-15-100m-Fly.txt', 'Blake-15-100m-Free.txt']
# Calvin ['Calvin-9-50m-Fly.txt', 'Calvin-9-50m-Free.txt', 'Calvin-9-50m-Back.txt', 'Calvin-9-50m-Fly.txt', 'Calvin-9-50m-Free.txt']
# Carl ['Carl-15-100m-Back.txt']
# Chris ['Chris-17-100m-Breast.txt', 'Chris-17-100m-Back.txt', 'Chris-17-100m-Breast.txt']
# Darius ['Darius-13-100m-Breast.txt', 'Darius-13-100m-Fly.txt', 'Darius-13-200m-IM.txt', 'Darius-13-100m-Back.txt', 'Darius-13-100m-Breast.txt', 'Darius-13-100m-Fly.txt', 'Darius-13-200m-IM.txt']
# Dave ['Dave-17-200m-Back.txt', 'Dave-17-100m-Free.txt', 'Dave-17-200m-Back.txt']
# Elba ['Elba-14-100m-Free.txt']
# Emma ['Emma-13-100m-Free.txt', 'Emma-13-100m-Breast.txt', 'Emma-13-100m-Free.txt']
# Erika ['Erika-15-100m-Free.txt', 'Erika-15-200m-Breast.txt', 'Erika-15-100m-Breast.txt', 'Erika-15-100m-Free.txt', 'Erika-15-200m-Breast.txt']
# Hannah ['Hannah-13-100m-Free.txt', 'Hannah-13-100m-Back.txt', 'Hannah-13-100m-Free.txt']
# Katie ['Katie-9-100m-Breast.txt', 'Katie-9-100m-Free.txt', 'Katie-9-50m-Back.txt', 'Katie-9-50m-Breast.txt', 'Katie-9-50m-Fly.txt', 'Katie-9-50m-Free.txt', 'Katie-9-100m-Back.txt', 'Katie-9-100m-Breast.txt', 'Katie-9-100m-Free.txt', 'Katie-9-50m-Back.txt', 'Katie-9-50m-Breast.txt', 'Katie-9-50m-Fly.txt', 'Katie-9-50m-Free.txt']
# Lizzie ['Lizzie-14-100m-Free.txt', 'Lizzie-14-100m-Back.txt', 'Lizzie-14-100m-Free.txt']
# Maria ['Maria-9-50m-Free.txt']
# Mike ['Mike-15-100m-Fly.txt', 'Mike-15-100m-Free.txt', 'Mike-15-200m-Free.txt', 'Mike-15-200m-IM.txt', 'Mike-15-100m-Back.txt', 'Mike-15-100m-Fly.txt', 'Mike-15-100m-Free.txt', 'Mike-15-200m-Free.txt', 'Mike-15-200m-IM.txt']
# Owen ['Owen-15-100m-Free.txt']
# Ruth ['Ruth-13-100m-Free.txt', 'Ruth-13-200m-Back.txt', 'Ruth-13-200m-Free.txt', 'Ruth-13-400m-Free.txt', 'Ruth-13-100m-Back.txt', 'Ruth-13-100m-Free.txt', 'Ruth-13-200m-Back.txt', 'Ruth-13-200m-Free.txt', 'Ruth-13-400m-Free.txt']
# Tasmin ['Tasmin-15-100m-Breast.txt', 'Tasmin-15-100m-Free.txt', 'Tasmin-15-200m-Breast.txt', 'Tasmin-15-100m-Back.txt', 'Tasmin-15-100m-Breast.txt', 'Tasmin-15-100m-Free.txt', 'Tasmin-15-200m-Breast.txt']

# %%
swimmers["Darius"]
# Out:
# ['Darius-13-100m-Breast.txt',
#  'Darius-13-100m-Fly.txt',
#  'Darius-13-200m-IM.txt',
#  'Darius-13-100m-Back.txt',
#  'Darius-13-100m-Breast.txt',
#  'Darius-13-100m-Fly.txt',
#  'Darius-13-200m-IM.txt']

# %%
import pprint

# %%
pprint.pprint(swimmers)
# Out:
# {'Abi': ['Abi-10-100m-Breast.txt',
#          'Abi-10-50m-Back.txt',
#          'Abi-10-50m-Breast.txt',
#          'Abi-10-50m-Free.txt',
#          'Abi-10-100m-Back.txt',
#          'Abi-10-100m-Breast.txt',
#          'Abi-10-50m-Back.txt',
#          'Abi-10-50m-Breast.txt',
#          'Abi-10-50m-Free.txt'],
#  'Ali': ['Ali-12-100m-Free.txt',
#          'Ali-12-100m-Back.txt',
#          'Ali-12-100m-Free.txt'],
#  'Alison': ['Alison-14-100m-Free.txt',
#             'Alison-14-100m-Breast.txt',
#             'Alison-14-100m-Free.txt'],
#  'Aurora': ['Aurora-13-50m-Free.txt'],
#  'Bill': ['Bill-18-200m-Back.txt',
#           'Bill-18-100m-Back.txt',
#           'Bill-18-200m-Back.txt'],
#  'Blake': ['Blake-15-100m-Fly.txt',
#            'Blake-15-100m-Free.txt',
#            'Blake-15-100m-Back.txt',
#            'Blake-15-100m-Fly.txt',
#            'Blake-15-100m-Free.txt'],
#  'Calvin': ['Calvin-9-50m-Fly.txt',
#             'Calvin-9-50m-Free.txt',
#             'Calvin-9-50m-Back.txt',
#             'Calvin-9-50m-Fly.txt',
#             'Calvin-9-50m-Free.txt'],
#  'Carl': ['Carl-15-100m-Back.txt'],
#  'Chris': ['Chris-17-100m-Breast.txt',
#            'Chris-17-100m-Back.txt',
#            'Chris-17-100m-Breast.txt'],
#  'Darius': ['Darius-13-100m-Breast.txt',
#             'Darius-13-100m-Fly.txt',
#             'Darius-13-200m-IM.txt',
#             'Darius-13-100m-Back.txt',
#             'Darius-13-100m-Breast.txt',
#             'Darius-13-100m-Fly.txt',
#             'Darius-13-200m-IM.txt'],
#  'Dave': ['Dave-17-200m-Back.txt',
#           'Dave-17-100m-Free.txt',
#           'Dave-17-200m-Back.txt'],
#  'Elba': ['Elba-14-100m-Free.txt'],
#  'Emma': ['Emma-13-100m-Free.txt',
#           'Emma-13-100m-Breast.txt',
#           'Emma-13-100m-Free.txt'],
#  'Erika': ['Erika-15-100m-Free.txt',
#            'Erika-15-200m-Breast.txt',
#            'Erika-15-100m-Breast.txt',
#            'Erika-15-100m-Free.txt',
#            'Erika-15-200m-Breast.txt'],
#  'Hannah': ['Hannah-13-100m-Free.txt',
#             'Hannah-13-100m-Back.txt',
#             'Hannah-13-100m-Free.txt'],
#  'Katie': ['Katie-9-100m-Breast.txt',
#            'Katie-9-100m-Free.txt',
#            'Katie-9-50m-Back.txt',
#            'Katie-9-50m-Breast.txt',
#            'Katie-9-50m-Fly.txt',
#            'Katie-9-50m-Free.txt',
#            'Katie-9-100m-Back.txt',
#            'Katie-9-100m-Breast.txt',
#            'Katie-9-100m-Free.txt',
#            'Katie-9-50m-Back.txt',
#            'Katie-9-50m-Breast.txt',
#            'Katie-9-50m-Fly.txt',
#            'Katie-9-50m-Free.txt'],
#  'Lizzie': ['Lizzie-14-100m-Free.txt',
#             'Lizzie-14-100m-Back.txt',
#             'Lizzie-14-100m-Free.txt'],
#  'Maria': ['Maria-9-50m-Free.txt'],
#  'Mike': ['Mike-15-100m-Fly.txt',
#           'Mike-15-100m-Free.txt',
#           'Mike-15-200m-Free.txt',
#           'Mike-15-200m-IM.txt',
#           'Mike-15-100m-Back.txt',
#           'Mike-15-100m-Fly.txt',
#           'Mike-15-100m-Free.txt',
#           'Mike-15-200m-Free.txt',
#           'Mike-15-200m-IM.txt'],
#  'Owen': ['Owen-15-100m-Free.txt'],
#  'Ruth': ['Ruth-13-100m-Free.txt',
#           'Ruth-13-200m-Back.txt',
#           'Ruth-13-200m-Free.txt',
#           'Ruth-13-400m-Free.txt',
#           'Ruth-13-100m-Back.txt',
#           'Ruth-13-100m-Free.txt',
#           'Ruth-13-200m-Back.txt',
#           'Ruth-13-200m-Free.txt',
#           'Ruth-13-400m-Free.txt'],
#  'Tasmin': ['Tasmin-15-100m-Breast.txt',
#             'Tasmin-15-100m-Free.txt',
#             'Tasmin-15-200m-Breast.txt',
#             'Tasmin-15-100m-Back.txt',
#             'Tasmin-15-100m-Breast.txt',
#             'Tasmin-15-100m-Free.txt',
#             'Tasmin-15-200m-Breast.txt']}

# %%
import os

import webbrowser

import swimclub

# %%
for fname in swimmers["Calvin"]:
    webbrowser.open(f"file://{os.path.realpath(swimclub.produce_bar_chart(fname))}")
