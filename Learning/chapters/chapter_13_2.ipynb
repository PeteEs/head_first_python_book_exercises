# %%
import data_utils

# %%
print([x for x in dir(data_utils) if not x.startswith("__")])
# Out:
# ['DBcm', 'SQL_CHART_DATA_BY_SWIMMER_EVENT_SESSION', 'SQL_SESSIONS', 'SQL_SWIMMERS_BY_SESSION', 'SQL_SWIMMERS_EVENTS_BY_SESSION', 'db_details', 'get_session_swimmers', 'get_swim_sessions', 'get_swimmers_events', 'get_swimmers_times']

# %%
help(data_utils.get_swim_sessions)
# Out:
# Help on function get_swim_sessions in module data_utils:
#
# get_swim_sessions()
#     Return a tuple-list of unique session timestamps.

# %%
data_utils.get_swim_sessions()
# Out:
# [('2026-01-11 14:22:00',),
#  ('2026-01-11 14:22:01',),
#  ('2026-01-12 00:39:30',),
#  ('2026-01-12 00:48:17',)]

# %%
data_utils.get_session_swimmers("2026-01-12")
# Out:
# [('Abi', 10),
#  ('Blake', 15),
#  ('Darius', 13),
#  ('Darius', 8),
#  ('Dave', 17),
#  ('Katie', 9),
#  ('Maria', 9),
#  ('Owen', 15)]

# %%
data_utils.get_swimmers_events("Darius", 8, "2026-01-12")
# Out:
# [('50m', 'Back'), ('50m', 'Breast'), ('50m', 'Free')]

# %%
data_utils.get_swimmers_times("Darius", 8, "50m", "Free", "2026-01-12")
# Out:
# [('39.42',),
#  ('36.13',),
#  ('37.66',),
#  ('39.07',),
#  ('39.42',),
#  ('36.13',),
#  ('37.66',),
#  ('39.07',)]

# %%
data = data_utils.get_swim_sessions()
data
# Out:
# [('2026-01-11 14:22:00',),
#  ('2026-01-11 14:22:01',),
#  ('2026-01-12 00:39:30',),
#  ('2026-01-12 00:48:17',)]

# %%
[t[0].split(" ")[0] for t in data]
# Out:
# ['2026-01-11', '2026-01-11', '2026-01-12', '2026-01-12']

# %%
data = data_utils.get_session_swimmers("2026-01-12")
data
# Out:
# [('Abi', 10),
#  ('Blake', 15),
#  ('Darius', 13),
#  ('Darius', 8),
#  ('Dave', 17),
#  ('Katie', 9),
#  ('Maria', 9),
#  ('Owen', 15)]

# %%
[f"{x[0]}-{x[1]}" for x in data]
# Out:
# ['Abi-10',
#  'Blake-15',
#  'Darius-13',
#  'Darius-8',
#  'Dave-17',
#  'Katie-9',
#  'Maria-9',
#  'Owen-15']

# %%
data = data_utils.get_swimmers_events("Darius", 8, "2026-01-12")
data
# Out:
# [('50m', 'Back'), ('50m', 'Breast'), ('50m', 'Free')]

# %%
[f"{x[0]} {x[1]}" for x in data]
# Out:
# ['50m Back', '50m Breast', '50m Free']

# %%
data = data_utils.get_swimmers_times("Darius", 8, "50m", "Free", "2026-01-12")
data
# Out:
# [('39.42',),
#  ('36.13',),
#  ('37.66',),
#  ('39.07',),
#  ('39.42',),
#  ('36.13',),
#  ('37.66',),
#  ('39.07',)]

# %%
[x[0] for x in data]
# Out:
# ['39.42', '36.13', '37.66', '39.07', '39.42', '36.13', '37.66', '39.07']

# %%
times = ['39.42', '36.13']

# %%
scaled = [357.23, 325.21]

# %%
zip(times, scaled)

# %%
list(zip(times, scaled))
# Out:
# [('39.42', 357.23), ('36.13', 325.21)]

# %%
for row in zip(times, scaled):
    print(row)
# Out:
# ('39.42', 357.23)
# ('36.13', 325.21)
